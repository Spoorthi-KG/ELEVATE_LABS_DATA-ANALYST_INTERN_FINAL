# %% [markdown]
# # HR Attrition Analysis Notebook\nThis notebook contains EDA, modeling and outputs. Refer to the exported outputs folder for final files.

# %%
# The full notebook is available in the repository. Run the provided scripts to reproduce results.
